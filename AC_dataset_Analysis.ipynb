# %%
import pandas as pd
import numpy as np
import dtale as dt

# %%
#!pip install pandas-profiling

# %% [markdown]
# ## Reading the Dataset into the jupyter notebook.
# Using the read_csv() method from pandas library to import the dataset of csv file format.
# Viewing the first five rows of the AC dataset using head().

# %%
data=pd.read_csv('AC_Data.csv')
data.head()
# Out:
#                      0      AC 1      AC 2  AC 3  AC 4      AC 5      AC 6  \
# 0  2019-08-01 00:00:00  7.518632  8.788315   0.0   0.0  2.617045  4.079041
# 1  2019-08-01 00:01:00       NaN       NaN   NaN   NaN       NaN       NaN
# 2  2019-08-01 00:02:00  7.426114  8.940615   0.0   0.0  2.581625  3.781231
# 3  2019-08-01 00:03:00       NaN       NaN   NaN   NaN       NaN       NaN
# 4  2019-08-01 00:04:00  7.052986  9.161103   0.0   0.0  2.592095  3.800127
#
#        AC 7      AC 8      AC 9     AC 10     AC 11     AC 12     AC 13  \
# 0  2.782276  4.624447  5.222060  2.151238  1.585072  0.560373  3.142941
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  2.529366  5.057423  5.349465  2.414715  2.168184  1.818730  3.085110
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4  2.332304  6.322521  3.995392  2.237114  3.345624  2.310409  3.132799
#
#       AC 14     AC 15     AC 16     AC 17     AC 18
# ...

# %%
# checking the shape of the dataset.
print("There are ", data.shape[0] ,"rows and", data.shape[1],"columns in our dataset.")
# Out:
# There are  87840 rows and 19 columns in our dataset.

# %%
# checking the data type and null values of each column.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87840 entries, 0 to 87839
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       87840 non-null  object
#  1   AC 1    43708 non-null  float64
#  2   AC 2    43711 non-null  float64
#  3   AC 3    43713 non-null  float64
#  4   AC 4    43704 non-null  float64
#  5   AC 5    43716 non-null  float64
#  6   AC 6    43717 non-null  float64
#  7   AC 7    43679 non-null  float64
#  8   AC 8    43704 non-null  float64
#  9   AC 9    43654 non-null  float64
#  10  AC 10   43690 non-null  float64
#  11  AC 11   43670 non-null  float64
#  12  AC 12   43713 non-null  float64
#  13  AC 13   43719 non-null  float64
#  14  AC 14   43696 non-null  float64
#  15  AC 15   43715 non-null  float64
#  16  AC 16   43710 non-null  float64
#  17  AC 17   43714 non-null  float64
#  18  AC 18   43723 non-null  float64
# dtypes: float64(18), object(1)
# memory usage: 12.7+ MB

# %%
# count of null values in each column
data.isnull().sum()
# Out:
# 0            0
# AC 1     44132
# AC 2     44129
# AC 3     44127
# AC 4     44136
# AC 5     44124
# AC 6     44123
# AC 7     44161
# AC 8     44136
# AC 9     44186
# AC 10    44150
# AC 11    44170
# AC 12    44127
# AC 13    44121
# AC 14    44144
# AC 15    44125
# AC 16    44130
# AC 17    44126
# AC 18    44117
# dtype: int64

# %% [markdown]
# It is evident from the initial analysis of the dataset that the dataset consists of more than 44117 missing values for each AC.

# %%
#descriptive statistics of the dataset
data.describe()
# Out:
#                AC 1          AC 2          AC 3          AC 4          AC 5  \
# count  43708.000000  43711.000000  43713.000000  43704.000000  43716.000000
# mean       2.379368      3.868892      2.568411      2.395158      1.421699
# std        2.276782      2.545147      1.487508      1.797529      0.767218
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      2.123263      1.706508      1.258299      0.970744
# 50%        2.094330      3.791752      2.486992      2.308961      1.380183
# 75%        3.661752      5.460892      3.441527      3.476123      1.870234
# max       11.194789     11.147141      8.430909      9.879500      5.495358
#
#                AC 6          AC 7          AC 8          AC 9         AC 10  \
# count  43717.000000  43679.000000  43704.000000  43654.000000  43690.000000
# mean       2.518138      2.980883      2.548711      3.184382      1.538344
# ...

# %% [markdown]
# 1.Changing the name of the first column to Date&Time and creating a new data frame with the changes.

# %%
df=data.rename(columns={'0':'date_time'})
df.head()
# Out:
#              date_time      AC 1      AC 2  AC 3  AC 4      AC 5      AC 6  \
# 0  2019-08-01 00:00:00  7.518632  8.788315   0.0   0.0  2.617045  4.079041
# 1  2019-08-01 00:01:00       NaN       NaN   NaN   NaN       NaN       NaN
# 2  2019-08-01 00:02:00  7.426114  8.940615   0.0   0.0  2.581625  3.781231
# 3  2019-08-01 00:03:00       NaN       NaN   NaN   NaN       NaN       NaN
# 4  2019-08-01 00:04:00  7.052986  9.161103   0.0   0.0  2.592095  3.800127
#
#        AC 7      AC 8      AC 9     AC 10     AC 11     AC 12     AC 13  \
# 0  2.782276  4.624447  5.222060  2.151238  1.585072  0.560373  3.142941
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  2.529366  5.057423  5.349465  2.414715  2.168184  1.818730  3.085110
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4  2.332304  6.322521  3.995392  2.237114  3.345624  2.310409  3.132799
#
#       AC 14     AC 15     AC 16     AC 17     AC 18
# ...

# %% [markdown]
# ## Changing the data type of  Date&Time

# %%
df['date_time']=pd.to_datetime(df['date_time'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87840 entries, 0 to 87839
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date_time  87840 non-null  datetime64[ns]
#  1   AC 1       43708 non-null  float64
#  2   AC 2       43711 non-null  float64
#  3   AC 3       43713 non-null  float64
#  4   AC 4       43704 non-null  float64
#  5   AC 5       43716 non-null  float64
#  6   AC 6       43717 non-null  float64
#  7   AC 7       43679 non-null  float64
#  8   AC 8       43704 non-null  float64
#  9   AC 9       43654 non-null  float64
#  10  AC 10      43690 non-null  float64
#  11  AC 11      43670 non-null  float64
#  12  AC 12      43713 non-null  float64
#  13  AC 13      43719 non-null  float64
#  14  AC 14      43696 non-null  float64
#  15  AC 15      43715 non-null  float64
#  16  AC 16      43710 non-null  float64
#  17  AC 17      43714 non-null  float64
#  18  AC 18      43723 non-null  float64
# ...

# %% [markdown]
# ## Using the dtale module for EDA .

# %%
d=dt.show(df)
d
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-JU15TH7:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### plot of dataset showing missing values
# It is evident from the plot that our dataset consists of large number of missing values.

# %% [markdown]
# ![missing values](missingno_matrix.png)

# %%
import sweetviz

# %%
my_report = sweetviz.analyze(df)
my_report
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
### create a whole report in form of HTML file
my_report.show_html('Report.html', open_browser=True)
                    
import IPython
IPython.display.HTML('Report.html')
# Out:
# Report Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <link rel="icon" href="data:image/x-icon;base64,..." type="image/x-icon" />
#         <script> /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# Before starting further analysis of the dataset, we need to collect and merge the temperature recorded in Gurgaon with our initial dataset.

# %% [markdown]
# ## Web Scrapping
# We will fetch the necessary data from the world weather online website.

# %%
# !pip install wwo_hist

# %%
from wwo_hist import retrieve_hist_data
import os
desktop=os.path.expanduser("/content")

# %%
start="1-AUG-2019"
end="30-SEPT-2019"
location_l=["Gurgaon"]
api_key='e9151d6cacdc4e32923204341222402'
frequency=3
hist_weather_data=retrieve_hist_data(api_key,location_l,start,end,frequency,location_label=False,export_csv=True,store_df=True)
# Out:
# Retrieving weather data for Gurgaon
#
#
# Currently retrieving data for Gurgaon: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.231628
# Currently retrieving data for Gurgaon: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.574755
#
#
# export Gurgaon completed!

# %% [markdown]
# ## Combining the scrapped weather data with the AC dataset.

# %% [markdown]
# After succesfully fetching the data ,the temperature data was collected at a frequency interval of 3 hours.But after the initial data exploration it is evident that
# the AC dataset contains data for every minute.
# 1. In order to deal with this it is assumed that the temperature is constant for 180 minutes and may change after 3 hours.
# 2. The reccuring missing values are indicatve of no power consumption.

# %%
df2=pd.DataFrame(hist_weather_data[0])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488 entries, 0 to 7
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          488 non-null    datetime64[ns]
#  1   maxtempC           488 non-null    object
#  2   mintempC           488 non-null    object
#  3   totalSnow_cm       488 non-null    object
#  4   sunHour            488 non-null    object
#  5   uvIndex            488 non-null    object
#  6   moon_illumination  488 non-null    object
#  7   moonrise           488 non-null    object
#  8   moonset            488 non-null    object
#  9   sunrise            488 non-null    object
#  10  sunset             488 non-null    object
#  11  DewPointC          488 non-null    object
#  12  FeelsLikeC         488 non-null    object
#  13  HeatIndexC         488 non-null    object
#  14  WindChillC         488 non-null    object
#  15  WindGustKmph       488 non-null    object
# ...

# %%
merged_dataset=pd.merge(df,df2,how='outer',on='date_time')
merged_dataset
# Out:
#                 date_time      AC 1      AC 2      AC 3      AC 4      AC 5  \
# 0     2019-08-01 00:00:00  7.518632  8.788315  0.000000  0.000000  2.617045
# 1     2019-08-01 00:01:00       NaN       NaN       NaN       NaN       NaN
# 2     2019-08-01 00:02:00  7.426114  8.940615  0.000000  0.000000  2.581625
# 3     2019-08-01 00:03:00       NaN       NaN       NaN       NaN       NaN
# 4     2019-08-01 00:04:00  7.052986  9.161103  0.000000  0.000000  2.592095
# ...                   ...       ...       ...       ...       ...       ...
# 87835 2019-09-30 23:55:00  0.000000  6.122385  2.192198  2.083315  1.046250
# 87836 2019-09-30 23:56:00       NaN       NaN       NaN       NaN       NaN
# 87837 2019-09-30 23:57:00  1.209176  6.152532  2.211421  0.000000  1.448103
# 87838 2019-09-30 23:58:00       NaN       NaN       NaN       NaN       NaN
# 87839 2019-09-30 23:59:00  1.430442  6.078281  1.891162  0.000000  1.577491
#
# ...

# %%
merged_dataset.shape
# Out:
# (87840, 43)

# %%
merged_dataset.columns
# Out:
# Index(['date_time', 'AC 1', 'AC 2', 'AC 3', 'AC 4', 'AC 5', 'AC 6', 'AC 7',
#        'AC 8', 'AC 9', 'AC 10', 'AC 11', 'AC 12', 'AC 13', 'AC 14', 'AC 15',
#        'AC 16', 'AC 17', 'AC 18', 'maxtempC', 'mintempC', 'totalSnow_cm',
#        'sunHour', 'uvIndex', 'moon_illumination', 'moonrise', 'moonset',
#        'sunrise', 'sunset', 'DewPointC', 'FeelsLikeC', 'HeatIndexC',
#        'WindChillC', 'WindGustKmph', 'cloudcover', 'humidity', 'precipMM',
#        'pressure', 'tempC', 'visibility', 'winddirDegree', 'windspeedKmph',
#        'location'],
#       dtype='object')

# %%
merged_dataset['tempC']=merged_dataset['tempC'].interpolate(method='ffill',limit=180)
merged_dataset['tempC']=merged_dataset['tempC'].astype(str).astype(int)
# merged_dataset.head(10)

# %%
final_df=pd.DataFrame(merged_dataset[['date_time','tempC', 'AC 1', 'AC 2', 'AC 3', 'AC 4', 'AC 5', 'AC 6', 'AC 7',
       'AC 8', 'AC 9', 'AC 10', 'AC 11', 'AC 12', 'AC 13', 'AC 14', 'AC 15',
       'AC 16', 'AC 17', 'AC 18']])
final_df=final_df.set_index('date_time')
final_df["tempC"].value_counts()
# Out:
# 33    10980
# 32    10260
# 31     9180
# 37     7380
# 35     7200
# 30     6840
# 34     6660
# 29     6120
# 36     5940
# 38     5040
# 27     3240
# 28     2880
# 39     1980
# 26     1620
# 25     1080
# 40      720
# 41      360
# 24      360
# Name: tempC, dtype: int64

# %% [markdown]
# After merging both the datasets and shaping it according to our need and setting the date and time as index.
# Now, we can find patterns hidden within our data.

# %%
final_df.info()
final_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87840 entries, 2019-08-01 00:00:00 to 2019-09-30 23:59:00
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tempC   87840 non-null  int32
#  1   AC 1    43708 non-null  float64
#  2   AC 2    43711 non-null  float64
#  3   AC 3    43713 non-null  float64
#  4   AC 4    43704 non-null  float64
#  5   AC 5    43716 non-null  float64
#  6   AC 6    43717 non-null  float64
#  7   AC 7    43679 non-null  float64
#  8   AC 8    43704 non-null  float64
#  9   AC 9    43654 non-null  float64
#  10  AC 10   43690 non-null  float64
#  11  AC 11   43670 non-null  float64
#  12  AC 12   43713 non-null  float64
#  13  AC 13   43719 non-null  float64
#  14  AC 14   43696 non-null  float64
#  15  AC 15   43715 non-null  float64
#  16  AC 16   43710 non-null  float64
#  17  AC 17   43714 non-null  float64
#  18  AC 18   43723 non-null  float64
# dtypes: float64(18), int32(1)
# ...

# %%
## percentage of nan values present in each feature
## 1 -step make the list of features which has missing values
features_with_na=[features for features in final_df.columns if final_df[features].isnull().sum()>1]

## 2- step print the feature name and the percentage of missing values

for feature in features_with_na:
    print(feature, np.round(merged_dataset[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# AC 1 0.5024  % missing values
# AC 2 0.5024  % missing values
# AC 3 0.5024  % missing values
# AC 4 0.5025  % missing values
# AC 5 0.5023  % missing values
# AC 6 0.5023  % missing values
# AC 7 0.5027  % missing values
# AC 8 0.5025  % missing values
# AC 9 0.503  % missing values
# AC 10 0.5026  % missing values
# AC 11 0.5028  % missing values
# AC 12 0.5024  % missing values
# AC 13 0.5023  % missing values
# AC 14 0.5026  % missing values
# AC 15 0.5023  % missing values
# AC 16 0.5024  % missing values
# AC 17 0.5023  % missing values
# AC 18 0.5022  % missing values

# %%
#Info about the type of columns and Exact No. of NULL Values
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87840 entries, 2019-08-01 00:00:00 to 2019-09-30 23:59:00
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tempC   87840 non-null  int32
#  1   AC 1    43708 non-null  float64
#  2   AC 2    43711 non-null  float64
#  3   AC 3    43713 non-null  float64
#  4   AC 4    43704 non-null  float64
#  5   AC 5    43716 non-null  float64
#  6   AC 6    43717 non-null  float64
#  7   AC 7    43679 non-null  float64
#  8   AC 8    43704 non-null  float64
#  9   AC 9    43654 non-null  float64
#  10  AC 10   43690 non-null  float64
#  11  AC 11   43670 non-null  float64
#  12  AC 12   43713 non-null  float64
#  13  AC 13   43719 non-null  float64
#  14  AC 14   43696 non-null  float64
#  15  AC 15   43715 non-null  float64
#  16  AC 16   43710 non-null  float64
#  17  AC 17   43714 non-null  float64
#  18  AC 18   43723 non-null  float64
# dtypes: float64(18), int32(1)
# ...

# %% [markdown]
# ## Identifying trends
# Using Visualization

# %%
#Let's plot some diagram for this relationship
import matplotlib.pyplot as plt
# %matplotlib inline
for feature in features_with_na:
    data = final_df.copy()
    
    # let's make a variable that indicates 1 if the observation was missing or zero otherwise
    data[feature] = np.where((data[feature].isnull()),1,0 )
    
    # let's calculate the mean of AC where the information is missing or present
    data.groupby(feature).mean()['tempC'].plot()
    plt.ylabel('Temprature')
    plt.xlabel('AC power consumption')
    plt.title(feature)
    plt.show()

# %% [markdown]
# This gives us more insight into our data and real-world scenarios. Clearly, there is a more upward trend and a recurring event where temprature is high AC Power consumption also high.
#
# There is a positive relationship between power Cosnumption and temperature. As temperature increases so does Power Cosnumption .

# %%
col='tempC'
final_df[col].plot(kind='line')
# Out:
# <AxesSubplot:xlabel='date_time'>

# %% [markdown]
# Which AC was used the most and used the least

# %%
numbers={'AC1':'43708.000000','AC2':'43711.000000','AC3':'43713.000000','AC4':'43704.000000',
       'AC5':'43716.000000','AC6':'43717.000000','AC7':'43679.000000','AC8':'43704.000000',
      'AC9': '43654.000000','AC10':'43690.000000','AC11':'43670.000000','AC12':'43713.000000',
       'AC13':'43719.000000','AC14':'43696.000000','AC15':'43715.000000','AC16':'43710.000000',
       'AC17':'43714.000000','AC18':'43723.000000'}

# %%
Keymax = max(zip(numbers.values(), numbers.keys(),))
print("The AC used most",Keymax)

Keymin = min(zip(numbers.values(), numbers.keys(),))
print("The AC used least",Keymin)
# Out:
# The AC used most ('43723.000000', 'AC18')
# The AC used least ('43654.000000', 'AC9')

# %%
## Lets analyze the tempC Variables
## We will check the relation between tempC and every AC to forecast the power consumption

l=['AC 1','AC 2','AC 3','AC 4','AC 5','AC 6','AC 7',
   'AC 8','AC 9','AC 10','AC 11','AC 12','AC 13',
   'AC 14','AC 15','AC 16','AC 17','AC 18']

final_df.groupby('tempC')[l].median().plot(figsize=(20,10))
plt.xlabel('Temprature')
plt.ylabel('AC')
plt.title("Forecasts for power consumption")
# Out:
# Text(0.5, 1.0, 'Forecasts for power consumption')

# %%
#for seasonal decompose we have to remove the NA values
df1=final_df.dropna()
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(df1['AC 5'],model='additive',period=1)
plt.figure(figsize=(20,15))
result.plot()
plt.show()



result = seasonal_decompose(df1['tempC'],model='additive',period=11)
plt.figure(figsize=(20,15))
result.plot()
plt.show()
